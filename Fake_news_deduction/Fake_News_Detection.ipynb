# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [raw]
# 1 - FAKE NEWS
# 0 - REAL NEWS

# %%
df = pd.read_csv(r"Datasets/train.csv")
df.shape
# Out:
# (20800, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
df.head(5)
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df.fillna(" ", inplace = True)
#you can do that or you can use this ode instead - df = df.filllna("" )

# %%
df.isnull().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
df["Content"] = df["author"] +" " + df["title"]

# %%
X = df
X
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %% [raw]
# STEMMING PROCEDURE

# %%
obj = PorterStemmer()
def Func_Stem(content):
    stemm_val = re.sub('[^a-zA-Z]', ' ', content)
    stemm_val = stemm_val.lower()
    stemm_val = stemm_val.split()
    lists = stemm_val[:]
    stemm_val.clear()
    for i in lists:
        if i not in stopwords.words('english'):
            stemm_val.append(obj.stem(i))
    return " ".join(stemm_val)

# %%
df["Stemmed_Column"] = df["Content"].apply(Func_Stem)

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
X = df["Stemmed_Column"].values
Y = df["label"].values
Y
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
X
# Out:
# array(['darrel lucu hous dem aid even see comey letter jason chaffetz tweet',
#        'daniel j flynn flynn hillari clinton big woman campu breitbart',
#        'consortiumnew com truth might get fire', ...,
#        'michael j de la merc rachel abram maci said receiv takeov approach hudson bay new york time',
#        'alex ansari nato russia hold parallel exercis balkan',
#        'david swanson keep f aliv'], dtype=object)

# %% [raw]
# CONVERT WORDS TO NUMBERS USING VECTORIZER FUNCTION

# %%
obj_vect = TfidfVectorizer()
obj_vect.fit(X) 
X = obj_vect.transform(X)

# %%
print(X)
# Out:
#   (0, 267)	0.2701012497770876
#   (0, 2483)	0.36765196867972083
#   (0, 2959)	0.24684501285337127
#   (0, 3600)	0.3598939188262558
#   (0, 3792)	0.27053324808454915
#   (0, 4973)	0.23331696690935097
#   (0, 7005)	0.2187416908935914
#   (0, 7692)	0.24785219520671598
#   (0, 8630)	0.2921251408704368
#   (0, 8909)	0.36359638063260746
#   (0, 13473)	0.2565896679337956
#   (0, 15686)	0.2848506356272864
#   (1, 1497)	0.2939891562094648
#   (1, 1894)	0.15521974226349364
#   (1, 2223)	0.3827320386859759
#   (1, 2813)	0.19094574062359204
#   (1, 3568)	0.26373768806048464
#   (1, 5503)	0.7143299355715573
#   (1, 6816)	0.1904660198296849
#   (1, 16799)	0.30071745655510157
#   (2, 2943)	0.3179886800654691
#   (2, 3103)	0.46097489583229645
#   (2, 5389)	0.3866530551182615
#   (2, 5968)	0.3474613386728292
#   (2, 9620)	0.49351492943649944
#   :	:
#   (20797, 3643)	0.2115550061362374
#   (20797, 7042)	0.21799048897828685
#   (20797, 8364)	0.22322585870464115
#   (20797, 8988)	0.36160868928090795
# ...

# %% [raw]
# SPLITTING THE DATASET INTO TRAINING AND TEXT DATA SET

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.2, stratify = Y, random_state = 2)

# %% [raw]
# SELCTING THE MODEL, HERE WE CHOSE LOGISTIC REGRESSION SINCE IT IS A BINARY CLASSIFICATION PROBLEM

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train_prediction = model.predict(x_train)
accuracy_data = accuracy_score(x_train_prediction, y_train)
accuracy_data
# Out:
# 0.9863581730769231

# %%
x_test_prediction = model.predict(x_test)
test_accuracy_data = accuracy_score(x_test_prediction, y_test)
test_accuracy_data
# Out:
# 0.9790865384615385

# %%
i = 10 #just for changing values in 2 places I have introduced i, nothing to do with the code...
x_new = x_test[i]
pred = model.predict(x_new[0])
print(pred)
if (pred[0]==1):
    print("The news is Fake")
else:
    print("The news is Real")

print(y_test[i])
# Out:
# [0]
# The news is Real
# 0

# %%
# Out:
# <1x17128 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>
